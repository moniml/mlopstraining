# %% [markdown]
# <a href="https://colab.research.google.com/github/moniml/mlopstraining/blob/main/test_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/social_media_addiction_dataset (1).csv")
df
# Out:
#      daily_screen_time  app_opens  sleep_hours  stress_level  \
# 0                  5.4         67          3.8             1
# 1                  4.3         10          6.9             2
# 2                  7.0         48          5.4             9
# 3                 12.0         16          6.7             2
# 4                  8.8         25          6.0             3
# ..                 ...        ...          ...           ...
# 995                2.8         49          6.6             7
# 996                6.5         76          5.4             7
# 997                6.5         22          6.6             1
# 998                4.0         40          4.3             8
# 999                5.0         27          6.2            10
#
#      study_interruptions night_usage addiction_level
# 0                      2          No        Moderate
# 1                      7          No             Low
# 2                      3          No        Moderate
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['sleep_hours'],df['daily_screen_time'])
plt.show()

# %%
plt.scatter(df['daily_screen_time'],df['app_opens'])
plt.show()

# %%
x=df[['sleep_hours','daily_screen_time']]
y=df['app_opens']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#      sleep_hours  daily_screen_time
# 346          5.2                7.2
# 930          4.4                9.9
# 216          5.6                8.2
# 229          4.3                5.3
# 692          7.8                1.2
# ..           ...                ...
# 648          7.8                6.9
# 630          7.1                2.9
# 466          4.3                9.1
# 560          4.7                7.0
# 795          4.0                6.0
#
# [700 rows x 2 columns]

# %%
x_test
# Out:
#      sleep_hours  daily_screen_time
# 801          5.9                4.4
# 536          8.9               11.0
# 180          6.1                4.8
# 588          7.9                5.0
# 311          5.1                5.6
# ..           ...                ...
# 54           5.5                7.9
# 976          4.6                3.3
# 700          8.8                1.5
# 887          3.1               11.2
# 800          3.6               11.1
#
# [300 rows x 2 columns]

# %%
y_train
# Out:
# 346    56
# 930    43
# 216    66
# 229    19
# 692     8
#        ..
# 648     5
# 630    66
# 466    74
# 560    48
# 795    67
# Name: app_opens, Length: 700, dtype: int64

# %%
y_test
# Out:
# 801    79
# 536    45
# 180    27
# 588    27
# 311    23
#        ..
# 54     10
# 976    70
# 700    25
# 887    57
# 800    44
# Name: app_opens, Length: 300, dtype: int64

# %% [markdown]
# run linear regression model

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(x_train,y_train);

# %%
x_test
# Out:
#      sleep_hours  daily_screen_time
# 801          5.9                4.4
# 536          8.9               11.0
# 180          6.1                4.8
# 588          7.9                5.0
# 311          5.1                5.6
# ..           ...                ...
# 54           5.5                7.9
# 976          4.6                3.3
# 700          8.8                1.5
# 887          3.1               11.2
# 800          3.6               11.1
#
# [300 rows x 2 columns]

# %%
clf.predict(x_test)
# Out:
# array([43.32764562, 39.8804136 , 43.10092089, 41.3231116 , 44.01819244,
#        45.59499812, 42.80984076, 44.18564282, 41.03192621, 42.44138677,
#        41.79730636, 45.99700535, 46.39107518, 43.74521183, 44.26799248,
#        44.46920663, 41.07839263, 42.67075729, 41.46484087, 45.97626003,
#        45.54874223, 41.43382817, 40.60419787, 42.68864627, 43.56738879,
#        41.67875767, 45.37600025, 43.39729262, 42.72728057, 41.90558766,
#        42.85091032, 44.2114692 , 41.90294187, 42.30209276, 40.4961271 ,
#        45.63098662, 41.8642023 , 43.35103673, 40.92131491, 42.48520739,
#        41.80492796, 43.60083676, 43.06218133, 43.56992932, 43.8506368 ,
#        40.12248678, 43.07011872, 40.04013712, 45.38393765, 41.7922253 ,
#        45.58981179, 43.55437034, 41.95713515, 43.71663439, 41.71728671,
#        46.23653799, 43.69345381, 42.6991242 , 45.64389981, 41.19175499,
#        41.61948333, 43.61629048, 46.15154254, 43.50028232, 44.1368464 ,
# ...

# %%
y_test
# Out:
# 801    79
# 536    45
# 180    27
# 588    27
# 311    23
#        ..
# 54     10
# 976    70
# 700    25
# 887    57
# 800    44
# Name: app_opens, Length: 300, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# -0.022165331789461895

# %% [markdown]
# model is very poor for regression hence the main taget is addiction_level which is classification

# %% [markdown]
# random state argument

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
x_test
# Out:
#      sleep_hours  daily_screen_time
# 913          3.4                1.9
# 370          7.3                9.3
# 880          6.1                5.1
# 111          6.2                3.5
# 422          9.0                6.2
# ..           ...                ...
# 973          5.6                1.6
# 400          9.0                6.6
# 263          8.1                7.6
# 674          5.0                1.8
# 147          6.1                8.4
#
# [300 rows x 2 columns]
